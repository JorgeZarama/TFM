# %%
import pandas as pd

# Carga el archivo .pkl completo
pkl_file = 'ruta_a_tu_archivo.pkl'
df = pd.read_pickle(pkl_file)

# Guardar como CSV
df.to_csv('archivo_grande.csv', index=False)
            break

# %%
import pandas as pd

# Ruta del archivo CSV grande
file_path = 'df_withcorona_clean_1_with_proba_opti_and_hour.csv'

# Define el tamaño del chunk en términos de número de filas
chunk_size = 10000  # Ajusta este número según lo necesites

# Itera sobre el archivo CSV en chunks
for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    print(f"Procesando chunk {i+1}")
    
    # Realiza alguna tarea de preprocesamiento en el chunk
    #chunk.fillna(chunk.mean(), inplace=True)  # Ejemplo de preprocesamiento
    
    # Muestra 10 ejemplos de filas
    print("Ejemplos de filas en este chunk:")
    display(chunk.head(20))  # Muestra las primeras 10 filas
    break
    # Guarda el chunk procesado si es necesario
    chunk.to_csv(f'processed_chunk_{i+1}.csv', index=False)
# Out:
# Procesando chunk 1
# Ejemplos de filas en este chunk:
#    ticker  id_msg                                                msg  \
# 0    AAPL  407487  @dustin i&amp;#39;m long $aapl or at least unt...
# 1    AAPL  407689                                        $aapl liver
# 2    AAPL  407691                      rt @howardlindzon $aapl liver
# 3    AAPL  407693    rt @howardlindzon rt @howardlindzon $aapl liver
# 4     DBV  408000                                               $dbv
# 5     FAZ  409626           so will $faz have 2 reverse split again?
# 6    SNDA  409682  set up a group called china adrs  @howardlindz...
# 7    NTES  409682  set up a group called china adrs  @howardlindz...
# 8     IYR  409890  sell -10 vertical $iyr 100 aug 09 32/34 call @...
# 9     RAX  410199  @sparkycollier isn&amp;#39;t that already the ...
# 10   AAPL  410448  apple touchscreen netbook to launch in october...
# 11    RAX  410797  @sorenmacbeth good point -- $rax is all about ...
# 12   AMZN  411119  @rosswhiting love $amzn and audible add in $nf...
# 13   NFLX  411119  @rosswhiting love $amzn and audible add in $nf...
# 14   AAPL  411415  @rosswhiting that&#39;s because apple&#39;s ti...
# 15   AAPL  411416             @howardlindzon that&#39;s iliver $aapl
# 16   AAPL  411435     $aapl non-removable battery thing is bad news.
# 17     GS  412319  $gs crushed numbers, what a shock. at least th...
# 18    CIT  421564  trying out the link feature, here&#39;s a stor...
# 19     GS  424540                      paulson wears $gs underpants.
#
#                          date  sent  id_user    foll   ideas  \
# 0   2009-07-10 21:47:36+00:00     0        2     607     964
# 1   2009-07-11 05:36:05+00:00     0        5  219918  140958
# 2   2009-07-11 05:38:01+00:00     0        5  219918  140958
# 3   2009-07-11 05:38:16+00:00     0        5  219918  140958
# 4   2009-07-11 23:36:44+00:00     0        3    1803     577
# 5   2009-07-13 15:22:31+00:00     0       10   11497    6829
# 6   2009-07-13 15:31:36+00:00     0       10   11498    6829
# 7   2009-07-13 15:31:36+00:00     0       10   11499    6829
# 8   2009-07-13 15:57:39+00:00     0       15   45586   11459
# 9   2009-07-13 16:53:44+00:00     0        3    1803     577
# 10  2009-07-13 17:44:22+00:00     0       24     230    1836
# 11  2009-07-13 19:11:30+00:00     0       22      50       6
# 12  2009-07-13 20:05:11+00:00     0        2     607     964
# 13  2009-07-13 20:05:11+00:00     0        2     607     964
# 14  2009-07-13 22:22:50+00:00     0        3    1803     577
# 15  2009-07-13 22:24:20+00:00     0       21      19      26
# 16  2009-07-13 22:43:54+00:00     0        3    1803     577
# 17  2009-07-14 13:58:53+00:00     0       17     431      19
# 18  2009-07-17 00:43:02+00:00     0       43   59450    9031
# 19  2009-07-17 20:55:18+00:00     0        3    1802     577
#
#                                            clean_text  sent_new  sent_merged  \
# 0    iampm long or at least until os be out next year         0            1
# 1                                               liver         1            1
# 2                                            rt liver         1            1
# 3                                         rt rt liver         1            1
# 4                                                 NaN         0            0
# 5                    so will have reverse split again        -1           -1
# 6   set up group call china adrs still the man his...         1            1
# 7   set up group call china adrs still the man his...         1            1
# 8   sell vertical aug call lmt we still use in fro...         1            1
# 9                isnampt that already the logo though         0            1
# 10  apple touchscreen netbook to launch in october...         1            1
# 11  good point be all about the hammer and sickle ...         0            1
# 12  love and audible add in and they just need to ...         1            1
# 13  love and audible add in and they just need to ...         1            1
# 14                 thats because apples ticker be not         0            1
# 15                                       thats iliver         0            1
# 16            non removable battery thing be bad news        -1           -1
# 17  crush number what shock at least the market is...        -1            0
# 18  try out the link feature heres story from bloo...         1            1
# 19                             paulson wear underpant         0            1
#
#     sent_new_noros  bullish_proba
# 0                1       0.836838
# 1                1       0.960147
# 2                1       0.951857
# 3                1       0.934311
# 4                1       0.842373
# 5               -1       0.336101
# 6                1       0.969949
# 7                1       0.969949
# 8                1       0.974189
# 9                1       0.834199
# 10               1       0.949052
# 11               1       0.791382
# 12               1       0.987668
# 13               1       0.987668
# 14               1       0.849567
# 15               1       0.846725
# 16              -1       0.321760
# 17               0       0.532236
# 18               1       0.958666
# 19               1       0.859577

# %%
import pandas as pd

# Ruta del archivo CSV grande
file_path = 'df_withcorona_clean_1_with_proba_opti_and_hour.csv'

# Define el tamaño del chunk en términos de número de filas
chunk_size = 10000  # Ajusta este número según lo necesites

# Inicializa una lista para acumular los chunks filtrados
filtered_chunks = []

# Itera sobre el archivo CSV en chunks
for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    print(f"Procesando chunk {i+1}")
    
    # Filtrar los registros que tienen "TMS" en la columna 'ticker'
    filtered_chunk = chunk[chunk['ticker'] == 'TMS']
    
    # Muestra 10 ejemplos de filas filtradas (si existen)
    if not filtered_chunk.empty:
        print("Ejemplos de filas filtradas en este chunk:")
        print(filtered_chunk.head(10))
        
        # Acumular los chunks filtrados
        filtered_chunks.append(filtered_chunk)

# Concatenar todos los chunks filtrados en un nuevo DataFrame
filtered_df = pd.concat(filtered_chunks, ignore_index=True)

# Guardar el nuevo DataFrame filtrado en un archivo CSV
filtered_df.to_csv('filtered_tms_records.csv', index=False)

print("Proceso completado. Los registros filtrados se han guardado en 'filtered_tms_records.csv'.")
# Out:
# Procesando chunk 1
# Procesando chunk 2
# Procesando chunk 3
# Procesando chunk 4
# Procesando chunk 5
# Procesando chunk 6
# Ejemplos de filas filtradas en este chunk:
#       ticker   id_msg                                                msg  \
# 59568    TMS  1097426  @dcha damn..now you know my secret :))  but i ...
#
#                             date  sent  id_user  foll  ideas  \
# 59568  2010-02-23 20:48:17+00:00     0     5644   970  10636
#
#                                               clean_text  sent_new  \
# 59568  damn now you know my secret but really do like...         1
#
#        sent_merged  sent_new_noros  bullish_proba
# 59568            1               1       0.946411
# Procesando chunk 7
# Ejemplos de filas filtradas en este chunk:
#       ticker   id_msg                                                msg  \
# 62657    TMS  1128144  $f seems to like that $tms fix is still flawed...
#
#                             date  sent  id_user  foll  ideas  \
# 62657  2010-03-04 14:48:43+00:00     0     5644   970  10636
#
#                                               clean_text  sent_new  \
# 62657  seem to like that fix be still flaw why the re...        -1
#
#        sent_merged  sent_new_noros  bullish_proba
# 62657            0               0       0.621551
# Procesando chunk 8
# Procesando chunk 9
# Procesando chunk 10
# Procesando chunk 11
# Procesando chunk 12
# Procesando chunk 13
# Procesando chunk 14
# Procesando chunk 15
# Procesando chunk 16
# Procesando chunk 17
# Procesando chunk 18
# Procesando chunk 19
# Procesando chunk 20
# Procesando chunk 21
# Procesando chunk 22
# Procesando chunk 23
# Procesando chunk 24
# Procesando chunk 25
# Procesando chunk 26
# Procesando chunk 27
# Procesando chunk 28
# Procesando chunk 29
# Procesando chunk 30
# Procesando chunk 31
# Procesando chunk 32
# Procesando chunk 33
# Procesando chunk 34
# Procesando chunk 35
# Procesando chunk 36
# Procesando chunk 37
# Procesando chunk 38
# Procesando chunk 39
# Procesando chunk 40
# Procesando chunk 41
# Procesando chunk 42
# Procesando chunk 43
# Procesando chunk 44
# Procesando chunk 45
# Procesando chunk 46
# Procesando chunk 47
# Procesando chunk 48
# Procesando chunk 49
# Procesando chunk 50
# Procesando chunk 51
# Procesando chunk 52
# Procesando chunk 53
# Procesando chunk 54
# Ejemplos de filas filtradas en este chunk:
#        ticker   id_msg                                                msg  \
# 535179    TMS  3411214  rt @ipotweet 8 ipos planned for the week of ap...
# 535396    TMS  3412140  watch kathy smith talk this week&#39;s $ipos o...
#
#                              date  sent  id_user   foll  ideas  \
# 535179  2011-04-11 14:37:39+00:00     0    37943    123   1131
# 535396  2011-04-11 15:16:05+00:00     0    67015  81321   6681
#
#                                              clean_text  sent_new  \
# 535179             rt ipos plan for the week of apr ipo         0
# 535396  watch kathy smith talk this weeks on cbnc today         1
#
#         sent_merged  sent_new_noros  bullish_proba
# 535179            1               1       0.813679
# 535396            1               1       0.899648
# Procesando chunk 55
# Ejemplos de filas filtradas en este chunk:
#        ticker   id_msg                                                msg  \
# 541031    TMS  3437514  3 other ipos also expected to trade tomorrow: ...
# 543267    TMS  3446974  the tale of four ipos - 2 priced strong: zipca...
# 543458    TMS  3447555  rt @ipotweet 4 ipos opening today: zipcar ($zi...
# 543473    TMS  3447778  rt @ipotweet 4 ipos opening today: zipcar ($zi...
# 543536    TMS  3448473  tms intl $tms ipo opens lower.  trading $12.35...
# 543648    TMS  3449145  box ships ($teu), tms international ($tms) hav...
# 545522    TMS  3459010  today&#39;s other $ipos both closed below thei...
# 548684    TMS  3473800  ipo investors were selective showing mixed ret...
#
#                              date  sent  id_user    foll  ideas  \
# 541031  2011-04-13 14:52:44+00:00     0    67015   81321   6681
# 543267  2011-04-14 12:46:22+00:00     0     8203  308823  34874
# 543458  2011-04-14 13:26:59+00:00     0    37943     123   1131
# 543473  2011-04-14 13:31:07+00:00     0      647  102892  19559
# 543536  2011-04-14 13:41:32+00:00     0     8203  308823  34874
# 543648  2011-04-14 13:57:29+00:00     0    67015   81321   6681
# 545522  2011-04-14 20:40:52+00:00     0    67015   81321   6681
# 548684  2011-04-16 01:44:59+00:00     0    67015   81321   6681
#
#                                                clean_text  sent_new  \
# 541031  other ipos also expect to trade tomorrow box s...         1
# 543267  the tale of ipos price strong zipcar amp arcos...         1
# 543458  rt ipos open today zipcar arcos dorados box sh...         1
# 543473  rt ipos open today zipcar arcos dorados box sh...         1
# 543536  tms intl ipo open lower trading after price sh...         0
# 543648  box ship tms international have underwhelme op...        -1
# 545522  todays other both close below their ipo price ...        -1
# 548684  ipo investor be selective show mixed return fo...         0
#
#         sent_merged  sent_new_noros  bullish_proba
# 541031            1               1       0.928247
# 543267            1               1       0.869396
# 543458            1               1       0.893383
# 543473            1               1       0.893383
# 543536            0               0       0.698745
# 543648           -1              -1       0.237755
# 545522           -1              -1       0.323725
# 548684            1               1       0.780729
# Procesando chunk 56
# Procesando chunk 57
# Procesando chunk 58
# Procesando chunk 59
# Procesando chunk 60
# Procesando chunk 61
# Procesando chunk 62
# Procesando chunk 63
# Procesando chunk 64
# Procesando chunk 65
# Procesando chunk 66
# Procesando chunk 67
# Procesando chunk 68
# Procesando chunk 69
# Procesando chunk 70
# Procesando chunk 71
# Procesando chunk 72
# Procesando chunk 73
# Procesando chunk 74
# Procesando chunk 75
# Procesando chunk 76
# Procesando chunk 77
# Procesando chunk 78
# Procesando chunk 79
# Procesando chunk 80
# Procesando chunk 81
# Procesando chunk 82
# Procesando chunk 83
# Procesando chunk 84
# Procesando chunk 85
# Procesando chunk 86
# Procesando chunk 87
# Procesando chunk 88
# Procesando chunk 89
# Procesando chunk 90
# Procesando chunk 91
# Procesando chunk 92
# Procesando chunk 93
# Procesando chunk 94
# Procesando chunk 95
# Procesando chunk 96
# Procesando chunk 97
# Procesando chunk 98
# Procesando chunk 99
# Procesando chunk 100
# Procesando chunk 101
# Procesando chunk 102
# Procesando chunk 103
# Procesando chunk 104
# Procesando chunk 105
# Procesando chunk 106
# Procesando chunk 107
# Procesando chunk 108
# Procesando chunk 109
# Procesando chunk 110
# Procesando chunk 111
# Procesando chunk 112
# Procesando chunk 113
# Procesando chunk 114
# Procesando chunk 115
# Procesando chunk 116
# Procesando chunk 117
# Procesando chunk 118
# Procesando chunk 119
# Procesando chunk 120
# Procesando chunk 121
# Procesando chunk 122
# Procesando chunk 123
# Procesando chunk 124
# Procesando chunk 125
# Procesando chunk 126
# Procesando chunk 127
# Procesando chunk 128
# Procesando chunk 129
# Procesando chunk 130
# Procesando chunk 131
# Procesando chunk 132
# Procesando chunk 133
# Procesando chunk 134
# Procesando chunk 135
# Procesando chunk 136
# Procesando chunk 137
# Procesando chunk 138
# Procesando chunk 139
# Procesando chunk 140
# Procesando chunk 141
# Procesando chunk 142
# Ejemplos de filas filtradas en este chunk:
#         ticker   id_msg                                                msg  \
# 1412801    TMS  6824308  listen to $tms q4 2011 earnings call (eps 0.16...
#
#                               date  sent  id_user    foll  ideas  \
# 1412801  2012-02-14 15:50:34+00:00     0    15852  115077  46430
#
#                                                 clean_text  sent_new  \
# 1412801  listen to earning call eps vs est live at am o...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 1412801            1               1       0.950313
# Procesando chunk 143
# Procesando chunk 144
# Procesando chunk 145
# Procesando chunk 146
# Procesando chunk 147
# Procesando chunk 148
# Procesando chunk 149
# Procesando chunk 150
# Procesando chunk 151
# Procesando chunk 152
# Procesando chunk 153
# Procesando chunk 154
# Procesando chunk 155
# Procesando chunk 156
# Procesando chunk 157
# Procesando chunk 158
# Procesando chunk 159
# Procesando chunk 160
# Procesando chunk 161
# Procesando chunk 162
# Procesando chunk 163
# Procesando chunk 164
# Procesando chunk 165
# Procesando chunk 166
# Procesando chunk 167
# Procesando chunk 168
# Procesando chunk 169
# Procesando chunk 170
# Procesando chunk 171
# Procesando chunk 172
# Procesando chunk 173
# Procesando chunk 174
# Procesando chunk 175
# Procesando chunk 176
# Procesando chunk 177
# Procesando chunk 178
# Procesando chunk 179
# Ejemplos de filas filtradas en este chunk:
#         ticker   id_msg                                                msg  \
# 1787352    TMS  7838215  listen to $tms q1 2012 earnings call - live at...
#
#                               date  sent  id_user    foll  ideas  \
# 1787352  2012-05-03 14:54:37+00:00     0    15852  115077  46430
#
#                                                clean_text  sent_new  \
# 1787352  listen to earning call live at am ondemand after         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 1787352            1               1       0.971853
# Procesando chunk 180
# Procesando chunk 181
# Procesando chunk 182
# Procesando chunk 183
# Procesando chunk 184
# Procesando chunk 185
# Procesando chunk 186
# Procesando chunk 187
# Procesando chunk 188
# Procesando chunk 189
# Procesando chunk 190
# Procesando chunk 191
# Procesando chunk 192
# Procesando chunk 193
# Procesando chunk 194
# Procesando chunk 195
# Procesando chunk 196
# Procesando chunk 197
# Procesando chunk 198
# Procesando chunk 199
# Procesando chunk 200
# Procesando chunk 201
# Procesando chunk 202
# Procesando chunk 203
# Procesando chunk 204
# Procesando chunk 205
# Procesando chunk 206
# Procesando chunk 207
# Procesando chunk 208
# Procesando chunk 209
# Procesando chunk 210
# Procesando chunk 211
# Procesando chunk 212
# Procesando chunk 213
# Procesando chunk 214
# Procesando chunk 215
# Procesando chunk 216
# Procesando chunk 217
# Procesando chunk 218
# Procesando chunk 219
# Procesando chunk 220
# Procesando chunk 221
# Procesando chunk 222
# Procesando chunk 223
# Procesando chunk 224
# Procesando chunk 225
# Procesando chunk 226
# Procesando chunk 227
# Procesando chunk 228
# Procesando chunk 229
# Procesando chunk 230
# Procesando chunk 231
# Procesando chunk 232
# Procesando chunk 233
# Procesando chunk 234
# Procesando chunk 235
# Procesando chunk 236
# Procesando chunk 237
# Procesando chunk 238
# Procesando chunk 239
# Procesando chunk 240
# Procesando chunk 241
# Procesando chunk 242
# Procesando chunk 243
# Procesando chunk 244
# Procesando chunk 245
# Procesando chunk 246
# Procesando chunk 247
# Procesando chunk 248
# Procesando chunk 249
# Procesando chunk 250
# Procesando chunk 251
# Procesando chunk 252
# Procesando chunk 253
# Procesando chunk 254
# Procesando chunk 255
# Procesando chunk 256
# Procesando chunk 257
# Procesando chunk 258
# Procesando chunk 259
# Procesando chunk 260
# Procesando chunk 261
# Procesando chunk 262
# Procesando chunk 263
# Procesando chunk 264
# Procesando chunk 265
# Procesando chunk 266
# Procesando chunk 267
# Procesando chunk 268
# Procesando chunk 269
# Procesando chunk 270
# Procesando chunk 271
# Procesando chunk 272
# Procesando chunk 273
# Procesando chunk 274
# Procesando chunk 275
# Procesando chunk 276
# Procesando chunk 277
# Procesando chunk 278
# Procesando chunk 279
# Procesando chunk 280
# Procesando chunk 281
# Procesando chunk 282
# Procesando chunk 283
# Procesando chunk 284
# Procesando chunk 285
# Procesando chunk 286
# Procesando chunk 287
# Procesando chunk 288
# Procesando chunk 289
# Procesando chunk 290
# Procesando chunk 291
# Procesando chunk 292
# Procesando chunk 293
# Procesando chunk 294
# Procesando chunk 295
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 2940959    TMS  10537030  sidoti starts tms international ($tms) at buy ...
#
#                               date  sent  id_user    foll  ideas  \
# 2940959  2012-11-14 16:14:38+00:00     0   182330  133355  79732
#
#                                     clean_text  sent_new  sent_merged  \
# 2940959  sidoti start tms international at buy         1            1
#
#          sent_new_noros  bullish_proba
# 2940959               1       0.996761
# Procesando chunk 296
# Procesando chunk 297
# Procesando chunk 298
# Procesando chunk 299
# Procesando chunk 300
# Procesando chunk 301
# Procesando chunk 302
# Procesando chunk 303
# Procesando chunk 304
# Procesando chunk 305
# Procesando chunk 306
# Procesando chunk 307
# Procesando chunk 308
# Procesando chunk 309
# Procesando chunk 310
# Procesando chunk 311
# Procesando chunk 312
# Procesando chunk 313
# Procesando chunk 314
# Procesando chunk 315
# Procesando chunk 316
# Procesando chunk 317
# Procesando chunk 318
# Procesando chunk 319
# Procesando chunk 320
# Procesando chunk 321
# Procesando chunk 322
# Procesando chunk 323
# Procesando chunk 324
# Procesando chunk 325
# Procesando chunk 326
# Procesando chunk 327
# Procesando chunk 328
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3270488    TMS  11325544  $tms tms international corp. announces new con...
# 3273705    TMS  11333597  $tms tms international corp. announces 2012 fo...
#
#                               date  sent  id_user  foll  ideas  \
# 3270488  2013-01-07 21:16:35+00:00     0   195124   109  44880
# 3273705  2013-01-08 14:16:12+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3270488  tms international corp announce new contract t...         1
# 3273705  tms international corp announce fourth quarter...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 3270488            1               1       0.981971
# 3273705            1               1       0.963276
# Procesando chunk 329
# Procesando chunk 330
# Procesando chunk 331
# Procesando chunk 332
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3319842    TMS  11441341  $tms tms international corp. promotes hideyuki...
#
#                               date  sent  id_user  foll  ideas  \
# 3319842  2013-01-14 13:53:10+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3319842  tms international corp promote hideyuki nishiz...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 3319842            1               1       0.919475
# Procesando chunk 333
# Procesando chunk 334
# Procesando chunk 335
# Procesando chunk 336
# Procesando chunk 337
# Procesando chunk 338
# Procesando chunk 339
# Procesando chunk 340
# Procesando chunk 341
# Procesando chunk 342
# Procesando chunk 343
# Procesando chunk 344
# Procesando chunk 345
# Procesando chunk 346
# Procesando chunk 347
# Procesando chunk 348
# Procesando chunk 349
# Procesando chunk 350
# Procesando chunk 351
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3508754    TMS  11882584  $tms tms international corp files 8-k.. http:/...
#
#                               date  sent  id_user  foll  ideas  \
# 3508754  2013-02-05 12:33:47+00:00     0   195124   109  44880
#
#                           clean_text  sent_new  sent_merged  sent_new_noros  \
# 3508754  tms international corp file         1            1               1
#
#          bullish_proba
# 3508754       0.933643
# Procesando chunk 352
# Procesando chunk 353
# Procesando chunk 354
# Procesando chunk 355
# Procesando chunk 356
# Procesando chunk 357
# Procesando chunk 358
# Procesando chunk 359
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3586261    TMS  12059020  $tms tms international corp. reports fourth qu...
# 3586503    TMS  12059572  $tms tms international corp files 8-k : result...
#
#                               date  sent  id_user  foll  ideas  \
# 3586261  2013-02-14 13:38:11+00:00     0   195124   109  44880
# 3586503  2013-02-14 13:58:06+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3586261  tms international corp report fourth quarter a...         1
# 3586503  tms international corp file result of operatio...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 3586261            1               1       0.938737
# 3586503            1               1       0.857134
# Procesando chunk 360
# Procesando chunk 361
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3604879    TMS  12101565  $tms tms international corp files 8-k : regula...
#
#                               date  sent  id_user  foll  ideas  \
# 3604879  2013-02-15 20:31:16+00:00     0   195124   109  44880
#
#                                          clean_text  sent_new  sent_merged  \
# 3604879  tms international corp files regulation fd         1            1
#
#          sent_new_noros  bullish_proba
# 3604879               1       0.890352
# Procesando chunk 362
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3613883    TMS  12123572  $tms tms international corp files 8-k : regula...
#
#                               date  sent  id_user  foll  ideas  \
# 3613883  2013-02-19 13:45:33+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3613883  tms international corp files regulation fd fin...         0
#
#          sent_merged  sent_new_noros  bullish_proba
# 3613883            1               1       0.744704
# Procesando chunk 363
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3621629    TMS  12140289  $tms tms international corp files form 10-k (a...
#
#                               date  sent  id_user  foll  ideas  \
# 3621629  2013-02-19 22:03:02+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3621629  tms international corp file form annual report...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 3621629            1               1       0.881599
# Procesando chunk 364
# Procesando chunk 365
# Procesando chunk 366
# Procesando chunk 367
# Procesando chunk 368
# Procesando chunk 369
# Procesando chunk 370
# Procesando chunk 371
# Procesando chunk 372
# Procesando chunk 373
# Procesando chunk 374
# Procesando chunk 375
# Procesando chunk 376
# Procesando chunk 377
# Procesando chunk 378
# Procesando chunk 379
# Procesando chunk 380
# Procesando chunk 381
# Procesando chunk 382
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3818388    TMS  12524172  watch list $bscg $bsci $bery $ebsb $frnk $fxcb...
#
#                               date  sent  id_user  foll  ideas  clean_text  \
# 3818388  2013-03-13 15:07:07+00:00     1   191131    94   1536  watch list
#
#          sent_new  sent_merged  sent_new_noros  bullish_proba
# 3818388         1            1               1       0.956989
# Procesando chunk 383
# Procesando chunk 384
# Procesando chunk 385
# Procesando chunk 386
# Procesando chunk 387
# Procesando chunk 388
# Procesando chunk 389
# Procesando chunk 390
# Procesando chunk 391
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3906547    TMS  12676082  $tms tms international corp. completes reprici...
#
#                               date  sent  id_user  foll  ideas  \
# 3906547  2013-03-21 20:32:17+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3906547  tms international corp complete repricing of t...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 3906547            1               1       0.893969
# Procesando chunk 392
# Procesando chunk 393
# Procesando chunk 394
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 3939547    TMS  12732116  $tms tms international corp. to hold annual me...
#
#                               date  sent  id_user  foll  ideas  \
# 3939547  2013-03-26 13:25:22+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 3939547  tms international corp to hold annual meeting ...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 3939547            1               1       0.877412
# Procesando chunk 395
# Procesando chunk 396
# Procesando chunk 397
# Procesando chunk 398
# Procesando chunk 399
# Procesando chunk 400
# Procesando chunk 401
# Procesando chunk 402
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4018107    TMS  12862374  $tms tms international corp. announces 2013 fi...
#
#                               date  sent  id_user  foll  ideas  \
# 4018107  2013-04-03 21:16:05+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 4018107  tms international corp announce first quarter ...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4018107            1               1       0.976037
# Procesando chunk 403
# Procesando chunk 404
# Procesando chunk 405
# Procesando chunk 406
# Procesando chunk 407
# Procesando chunk 408
# Procesando chunk 409
# Procesando chunk 410
# Procesando chunk 411
# Procesando chunk 412
# Procesando chunk 413
# Procesando chunk 414
# Procesando chunk 415
# Procesando chunk 416
# Procesando chunk 417
# Procesando chunk 418
# Procesando chunk 419
# Procesando chunk 420
# Procesando chunk 421
# Procesando chunk 422
# Procesando chunk 423
# Procesando chunk 424
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4233661    TMS  13218436  $tms tms international corp. reports first qua...
# 4236964    TMS  13223754  listen to $tms q1 2013 earnings call - live at...
#
#                               date  sent  id_user    foll  ideas  \
# 4233661  2013-04-25 12:30:03+00:00     0   195124     109  44880
# 4236964  2013-04-25 14:51:15+00:00     0    15852  115077  46430
#
#                                                 clean_text  sent_new  \
# 4233661  tms international corp report first quarter fi...         1
# 4236964   listen to earning call live at am ondemand after         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4233661            1               1       0.965358
# 4236964            1               1       0.971853
# Procesando chunk 425
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4242998    TMS  13233998  worth checking out admissions presented in the...
#
#                               date  sent  id_user  foll    ideas  \
# 4242998  2013-04-25 19:09:03+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 4242998  worth check out admission present in the confe...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4242998            1               1       0.963808
# Procesando chunk 426
# Procesando chunk 427
# Procesando chunk 428
# Procesando chunk 429
# Procesando chunk 430
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4299742    TMS  13323309  $jpm michael gambardella buy $tms -high custom...
#
#                               date  sent  id_user   foll  ideas  \
# 4299742  2013-05-01 15:06:39+00:00     0   217593  74304  37239
#
#                                                 clean_text  sent_new  \
# 4299742  michael gambardella buy high customer retentio...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4299742            1               1       0.904475
# Procesando chunk 431
# Procesando chunk 432
# Procesando chunk 433
# Procesando chunk 434
# Procesando chunk 435
# Procesando chunk 436
# Procesando chunk 437
# Procesando chunk 438
# Procesando chunk 439
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4387266    TMS  13461922  tms international corp. just filed its quarter...
#
#                               date  sent  id_user  foll    ideas  \
# 4387266  2013-05-08 20:41:12+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 4387266  tms international corp just file its quarterly...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4387266            1               1       0.910793
# Procesando chunk 440
# Procesando chunk 441
# Procesando chunk 442
# Procesando chunk 443
# Procesando chunk 444
# Procesando chunk 445
# Procesando chunk 446
# Procesando chunk 447
# Procesando chunk 448
# Procesando chunk 449
# Procesando chunk 450
# Procesando chunk 451
# Procesando chunk 452
# Procesando chunk 453
# Procesando chunk 454
# Procesando chunk 455
# Procesando chunk 456
# Procesando chunk 457
# Procesando chunk 458
# Procesando chunk 459
# Procesando chunk 460
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4596528    TMS  13803552  $tms tms international corp. to present at key...
#
#                               date  sent  id_user  foll  ideas  \
# 4596528  2013-05-28 22:06:07+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 4596528  tms international corp to present at keybanc c...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4596528            1               1       0.977023
# Procesando chunk 461
# Procesando chunk 462
# Procesando chunk 463
# Procesando chunk 464
# Procesando chunk 465
# Procesando chunk 466
# Procesando chunk 467
# Procesando chunk 468
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4679444    TMS  13942436  competitor comments (re: copart) read the brie...
#
#                               date  sent  id_user  foll  ideas  \
# 4679444  2013-06-05 14:54:30+00:00     0   190905    22   1410
#
#                                           clean_text  sent_new  sent_merged  \
# 4679444  competitor comment re copart read the brief         0            1
#
#          sent_new_noros  bullish_proba
# 4679444               1       0.821541
# Procesando chunk 469
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4686374    TMS  13953852  $tms stockholders re-elect eight incumbents to...
#
#                               date  sent  id_user  foll  ideas  \
# 4686374  2013-06-05 20:19:55+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 4686374  stockholder re elect incumbent to tms internat...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4686374            1               1       0.846698
# Procesando chunk 470
# Procesando chunk 471
# Procesando chunk 472
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 4713659    TMS  14000737  tms international corp. just filed its stateme...
#
#                               date  sent  id_user  foll    ideas  \
# 4713659  2013-06-07 21:06:05+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 4713659  tms international corp just file its statement...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 4713659            1               1       0.946746
# Procesando chunk 473
# Procesando chunk 474
# Procesando chunk 475
# Procesando chunk 476
# Procesando chunk 477
# Procesando chunk 478
# Procesando chunk 479
# Procesando chunk 480
# Procesando chunk 481
# Procesando chunk 482
# Procesando chunk 483
# Procesando chunk 484
# Procesando chunk 485
# Procesando chunk 486
# Procesando chunk 487
# Procesando chunk 488
# Procesando chunk 489
# Procesando chunk 490
# Procesando chunk 491
# Procesando chunk 492
# Procesando chunk 493
# Procesando chunk 494
# Procesando chunk 495
# Procesando chunk 496
# Procesando chunk 497
# Procesando chunk 498
# Procesando chunk 499
# Procesando chunk 500
# Procesando chunk 501
# Procesando chunk 502
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5016601    TMS  14521543  2day&#39;s top #breakout ideas: $acls $alr $bn...
#
#                               date  sent  id_user   foll  ideas  \
# 5016601  2013-07-10 19:22:21+00:00     0   218770  11590   4071
#
#                      clean_text  sent_new  sent_merged  sent_new_noros  \
# 5016601  days top breakout idea         1            1               1
#
#          bullish_proba
# 5016601       0.996409
# Procesando chunk 503
# Procesando chunk 504
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5032740    TMS  14549297  $tms tms international corp. announces 2013 se...
#
#                               date  sent  id_user  foll  ideas  \
# 5032740  2013-07-11 20:16:49+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 5032740  tms international corp announce second quarter...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5032740            1               1       0.967458
# Procesando chunk 505
# Procesando chunk 506
# Procesando chunk 507
# Procesando chunk 508
# Procesando chunk 509
# Procesando chunk 510
# Procesando chunk 511
# Procesando chunk 512
# Procesando chunk 513
# Procesando chunk 514
# Procesando chunk 515
# Procesando chunk 516
# Procesando chunk 517
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5161413    TMS  14760414  cleartrend research downgrades us iron &amp; s...
#
#                               date  sent  id_user  foll  ideas  \
# 5161413  2013-07-24 14:38:03+00:00     0   217475   163   3958
#
#                                                 clean_text  sent_new  \
# 5161413  cleartrend research downgrade us iron amp stee...         0
#
#          sent_merged  sent_new_noros  bullish_proba
# 5161413            1               1       0.836692
# Procesando chunk 518
# Procesando chunk 519
# Procesando chunk 520
# Procesando chunk 521
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5203827    TMS  14830145  $tms tms international corp. declares quarterl...
#
#                               date  sent  id_user  foll  ideas  \
# 5203827  2013-07-26 20:34:06+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 5203827  tms international corp declare quarterly dividend         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5203827            1               1       0.953845
# Procesando chunk 522
# Procesando chunk 523
# Procesando chunk 524
# Procesando chunk 525
# Procesando chunk 526
# Procesando chunk 527
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5260495    TMS  14919629  $tms tms international corp. reports second qu...
# 5260671    TMS  14919890  tms international corp. just filed its current...
#
#                               date  sent  id_user  foll    ideas  \
# 5260495  2013-08-01 12:37:03+00:00     0   195124   109    44880
# 5260671  2013-08-01 12:46:12+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 5260495  tms international corp report second quarter f...         1
# 5260671  tms international corp just file its current r...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5260495            1               1       0.967832
# 5260671            1               1       0.917111
# Procesando chunk 528
# Procesando chunk 529
# Procesando chunk 530
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5292348    TMS  14969642  worth checking out notes provided wrt $tms ear...
#
#                               date  sent  id_user  foll    ideas  \
# 5292348  2013-08-03 07:04:05+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 5292348  worth check out note provide wrt earning call ...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5292348            1               1       0.967238
# Procesando chunk 531
# Procesando chunk 532
# Procesando chunk 533
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5325781    TMS  15021613  tms international corp. just filed its quarter...
#
#                               date  sent  id_user  foll    ideas  \
# 5325781  2013-08-06 20:36:47+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 5325781  tms international corp just file its quarterly...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5325781            1               1       0.910793
# Procesando chunk 534
# Procesando chunk 535
# Procesando chunk 536
# Procesando chunk 537
# Procesando chunk 538
# Procesando chunk 539
# Procesando chunk 540
# Procesando chunk 541
# Procesando chunk 542
# Procesando chunk 543
# Procesando chunk 544
# Procesando chunk 545
# Procesando chunk 546
# Procesando chunk 547
# Procesando chunk 548
# Procesando chunk 549
# Procesando chunk 550
# Procesando chunk 551
# Procesando chunk 552
# Procesando chunk 553
# Procesando chunk 554
# Procesando chunk 555
# Procesando chunk 556
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5558232    TMS  15404788  $tms the pritzker organization announces acqui...
# 5558369    TMS  15405030  the pritzker organization announces acquisitio...
#
#                               date  sent  id_user  foll    ideas  \
# 5558232  2013-08-26 11:02:19+00:00     0   195124   109    44880
# 5558369  2013-08-26 11:41:05+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 5558232  the pritzker organization announce acquisition...         1
# 5558369  the pritzker organization announce acquisition...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5558232            1               1       0.967691
# 5558369            1               1       0.958959
# Procesando chunk 557
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5560847    TMS  15408341  gainers: $tms+11.62% $qihu+9.54% $ipi+8.14% \n...
# 5562947    TMS  15411398  top gainers on the all-time high list today: $...
# 5563029    TMS  15411512  &quot;@stocktwits50: top gainers on the all-ti...
# 5564191    TMS  15413156  gainers: $prta+18.60% $bcrx+13.02% $tms+12.14%...
# 5565160    TMS  15414692  tms international nets debt financing for appr...
#
#                               date  sent  id_user   foll  ideas  \
# 5560847  2013-08-26 14:00:03+00:00     0   244497  25548  23195
# 5562947  2013-08-26 15:15:47+00:00     0    23986  60230   6279
# 5563029  2013-08-26 15:18:27+00:00     0       27  30898  15349
# 5564191  2013-08-26 16:00:02+00:00     0   244497  25548  23195
# 5565160  2013-08-26 16:42:44+00:00     0    81029  21537  19214
#
#                                                 clean_text  sent_new  \
# 5560847                    gainer loser stock mover report         0
# 5562947     top gainer on the all time high list today etc         1
# 5563029  quot top gainer on the all time high list toda...         1
# 5564191                    gainer loser stock mover report         0
# 5565160  tms international nets debt financing for appr...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5560847            1               1       0.777395
# 5562947            1               1       0.978848
# 5563029            1               1       0.983077
# 5564191            1               1       0.777395
# 5565160            1               1       0.962041
# Procesando chunk 558
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5571434    TMS  15424376  movers for today. $yrcw, $bcrx, $tms, $usu, $n...
# 5574130    TMS  15428871  macd cross-up $amgn $chk $qihu $plug $x $gsta ...
#
#                               date  sent  id_user   foll  ideas  \
# 5571434  2013-08-26 22:35:42+00:00     0   244497  25548  23195
# 5574130  2013-08-27 09:39:47+00:00     0     2503  67468  67918
#
#               clean_text  sent_new  sent_merged  sent_new_noros  bullish_proba
# 5571434  mover for today         1            1               1       0.979912
# 5574130    macd cross up         1            1               1       0.992188
# Procesando chunk 559
# Procesando chunk 560
# Procesando chunk 561
# Procesando chunk 562
# Procesando chunk 563
# Procesando chunk 564
# Procesando chunk 565
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5645219    TMS  15552071  keybanc downgrades tms international ($tms) to...
#
#                               date  sent  id_user    foll  ideas  \
# 5645219  2013-09-03 17:44:38+00:00     0   182330  133355  79732
#
#                                           clean_text  sent_new  sent_merged  \
# 5645219  keybanc downgrade tms international to hold         1            1
#
#          sent_new_noros  bullish_proba
# 5645219               1       0.812629
# Procesando chunk 566
# Procesando chunk 567
# Procesando chunk 568
# Procesando chunk 569
# Procesando chunk 570
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5697952    TMS  15638918  tms international corp. just filed its prelimi...
#
#                               date  sent  id_user  foll    ideas  \
# 5697952  2013-09-06 20:06:23+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 5697952  tms international corp just file its prelimina...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5697952            1               1       0.975299
# Procesando chunk 571
# Procesando chunk 572
# Procesando chunk 573
# Procesando chunk 574
# Procesando chunk 575
# Procesando chunk 576
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5751983    TMS  15728487  tms international eyes $875m of debt backing a...
#
#                               date  sent  id_user   foll  ideas  \
# 5751983  2013-09-11 15:59:19+00:00     0    81029  21537  19214
#
#                                                 clean_text  sent_new  \
# 5751983  tms international eye of debt backing acquisit...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5751983            1               1       0.951606
# Procesando chunk 577
# Procesando chunk 578
# Procesando chunk 579
# Procesando chunk 580
# Procesando chunk 581
# Procesando chunk 582
# Procesando chunk 583
# Procesando chunk 584
# Procesando chunk 585
# Procesando chunk 586
# Procesando chunk 587
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5863052    TMS  15912988  tms international sets monday launch of $400m ...
#
#                               date  sent  id_user   foll  ideas  \
# 5863052  2013-09-19 15:09:32+00:00     0    81029  21537  19214
#
#                                                 clean_text  sent_new  \
# 5863052  tms international set monday launch of leverag...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5863052            1               1         0.9753
# Procesando chunk 588
# Procesando chunk 589
# Procesando chunk 590
# Procesando chunk 591
# Procesando chunk 592
# Procesando chunk 593
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5920486    TMS  16006324  tms international outlines offer price as $400...
#
#                               date  sent  id_user   foll  ideas  \
# 5920486  2013-09-23 21:52:30+00:00     0    81029  21537  19214
#
#                                                 clean_text  sent_new  \
# 5920486  tms international outlines offer price as leve...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5920486            1               1       0.886284
# Procesando chunk 594
# Procesando chunk 595
# Procesando chunk 596
# Procesando chunk 597
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 5966273    TMS  16084267  tms international corp. just filed its definit...
#
#                               date  sent  id_user  foll    ideas  \
# 5966273  2013-09-26 14:51:17+00:00     0   210967  4405  1643602
#
#                                                 clean_text  sent_new  \
# 5966273  tms international corp just file its definitiv...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 5966273            1               1       0.971184
# Procesando chunk 598
# Procesando chunk 599
# Procesando chunk 600
# Procesando chunk 601
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6001671    TMS  16149317  $tms tms international corp. announces propose...
# 6001867    TMS  16149575  $tms tms international corp files 8-k : other ...
# 6001869    TMS  16149577  tms international corp. announces proposed off...
# 6003923    TMS  16152742  tms international launches $300m of bonds to f...
#
#                               date  sent  id_user   foll    ideas  \
# 6001671  2013-09-30 10:32:17+00:00     0   195124    109    44880
# 6001867  2013-09-30 11:15:48+00:00     0   195124    109    44880
# 6001869  2013-09-30 11:16:04+00:00     0   210967   4405  1643602
# 6003923  2013-09-30 13:44:25+00:00     0    81029  21537    19214
#
#                                                 clean_text  sent_new  \
# 6001671  tms international corp announce propose offeri...         0
# 6001867  tms international corp files other event finan...         1
# 6001869  tms international corp announce propose offeri...         1
# 6003923  tms international launch of bond to fund pritz...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 6001671            1               1       0.802757
# 6001867            1               1       0.792315
# 6001869            1               1       0.813737
# 6003923            1               1       0.938013
# Procesando chunk 602
# Procesando chunk 603
# Procesando chunk 604
# Procesando chunk 605
# Procesando chunk 606
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6058668    TMS  16243881  tms international recuts structure, trims leve...
#
#                               date  sent  id_user   foll  ideas  \
# 6058668  2013-10-03 14:14:22+00:00     0    81029  21537  19214
#
#                                                 clean_text  sent_new  \
# 6058668  tms international recut structure trim leverag...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 6058668            1               1       0.840401
# Procesando chunk 607
# Procesando chunk 608
# Procesando chunk 609
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6085834    TMS  16290614  $tms tms international corp files 8-k : other ...
# 6085837    TMS  16290624  tms international leveraged loan enters second...
# 6085876    TMS  16290658  tms international corp. announces pricing of h...
#
#                               date  sent  id_user   foll    ideas  \
# 6085834  2013-10-04 21:13:38+00:00     0   195124    109    44880
# 6085837  2013-10-04 21:14:20+00:00     0    81029  21537    19214
# 6085876  2013-10-04 21:16:19+00:00     0   210967   4405  1643602
#
#                                                 clean_text  sent_new  \
# 6085834  tms international corp files other event finan...         1
# 6085837  tms international leveraged loan enter seconda...        -1
# 6085876         tms international corp announce pricing of         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 6085834            1               1       0.792315
# 6085837           -1              -1       0.453891
# 6085876            1               1       0.917426
# Procesando chunk 610
# Procesando chunk 611
# Procesando chunk 612
# Procesando chunk 613
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6120529    TMS  16348832  tms international corp. just filed its stateme...
# 6121101    TMS  16349772  cliff asness, aqr capital just made a couple b...
# 6122456    TMS  16352230  $tms, 13g filed by aqr delta master acccount, ...
#
#                               date  sent  id_user   foll    ideas  \
# 6120529  2013-10-08 18:41:08+00:00     0   210967   4405  1643602
# 6121101  2013-10-08 19:01:00+00:00     0   229229    223     3520
# 6122456  2013-10-08 19:48:58+00:00     0   210931  85364    26679
#
#                                                 clean_text  sent_new  \
# 6120529  tms international corp just file its statement...         1
# 6121101  cliff asness aqr capital just make couple big ...         0
# 6122456                file by aqr delta master account lp         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 6120529            1               1       0.977539
# 6121101            1               1       0.766405
# 6122456            1               1       0.867130
# Procesando chunk 614
# Procesando chunk 615
# Procesando chunk 616
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6159625    TMS  16414864  $tms tms international corp. receives 43 safet...
#
#                               date  sent  id_user  foll  ideas  \
# 6159625  2013-10-10 20:20:41+00:00     0   195124   109  44880
#
#                                                 clean_text  sent_new  \
# 6159625  tms international corp receive safety award fr...         1
#
#          sent_merged  sent_new_noros  bullish_proba
# 6159625            1               1       0.959154
# Procesando chunk 617
# Procesando chunk 618
# Procesando chunk 619
# Procesando chunk 620
# Procesando chunk 621
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6200130    TMS  16486765  raymond james downgrades tms international ($t...
#
#                               date  sent  id_user    foll  ideas  \
# 6200130  2013-10-15 11:08:50+00:00     0   182330  133355  79732
#
#                                                 clean_text  sent_new  \
# 6200130  raymond james downgrade tms international to m...         0
#
#          sent_merged  sent_new_noros  bullish_proba
# 6200130            1               1        0.76193
# Procesando chunk 622
# Procesando chunk 623
# Procesando chunk 624
# Ejemplos de filas filtradas en este chunk:
#         ticker    id_msg                                                msg  \
# 6233526    TMS  16542552  $tms the pritzker organization announces compl...
# 6234253    TMS  16543645  $tms tms international corp files form 8-k (ev...
#
#                               date  sent  id_user  foll  ideas  \
# ...
# Procesando chunk 3824
# Procesando chunk 3825
# Procesando chunk 3826
# Procesando chunk 3827
# Procesando chunk 3828
# Procesando chunk 3829
# Procesando chunk 3830
# Procesando chunk 3831
# Procesando chunk 3832
# Procesando chunk 3833
# Procesando chunk 3834
# Procesando chunk 3835
# Procesando chunk 3836
# Procesando chunk 3837
# Procesando chunk 3838
# Procesando chunk 3839
# Procesando chunk 3840
# Procesando chunk 3841
# Procesando chunk 3842
# Procesando chunk 3843
# Procesando chunk 3844
# Procesando chunk 3845
# Procesando chunk 3846
# Procesando chunk 3847
# Procesando chunk 3848
# Procesando chunk 4488
# Procesando chunk 4489
# Procesando chunk 4490
# Procesando chunk 4491
# Procesando chunk 4492
# Procesando chunk 4493
# Procesando chunk 4494
# Procesando chunk 4495
# Procesando chunk 4496
# Procesando chunk 4497
# Procesando chunk 4498
# Procesando chunk 4499
# Procesando chunk 4500
# Procesando chunk 4501
# Procesando chunk 4502
# Procesando chunk 4503
# Procesando chunk 4504
# Procesando chunk 4505
# Procesando chunk 4506
# Procesando chunk 4507
# Procesando chunk 4508
# Procesando chunk 4509
# Procesando chunk 4510
# Procesando chunk 4511
# Procesando chunk 4512
# Procesando chunk 4513
# Procesando chunk 4514
# Procesando chunk 4515
# Procesando chunk 4516
# Procesando chunk 4517
# Procesando chunk 4518
# Procesando chunk 4519
# Procesando chunk 4520
# Procesando chunk 4521
# Procesando chunk 4522
# Procesando chunk 4523
# Procesando chunk 4524
# Procesando chunk 4525
# Procesando chunk 4526
# Procesando chunk 4527
# Procesando chunk 4528
# Procesando chunk 4529
# Procesando chunk 4530
# Procesando chunk 4531
# Procesando chunk 4532
# Procesando chunk 4533
# Procesando chunk 4534
# Procesando chunk 4535
# Procesando chunk 4536
# Procesando chunk 4537
# Procesando chunk 4538
# Procesando chunk 4539
# Procesando chunk 4540
# Procesando chunk 4541
# Procesando chunk 4542
# Procesando chunk 4543
# Procesando chunk 4544
# Procesando chunk 4545
# Procesando chunk 4546
# Proceso completado. Los registros filtrados se han guardado en 'filtered_tms_records.csv'.

# %%
display(filtered_df)
# Out:
#    ticker    id_msg                                                msg  \
# 0     TMS   1097426  @dcha damn..now you know my secret :))  but i ...
# 1     TMS   1128144  $f seems to like that $tms fix is still flawed...
# 2     TMS   3411214  rt @ipotweet 8 ipos planned for the week of ap...
# 3     TMS   3412140  watch kathy smith talk this week&#39;s $ipos o...
# 4     TMS   3437514  3 other ipos also expected to trade tomorrow: ...
# ..    ...       ...                                                ...
# 81    TMS  58444987  $tms [2016-may] correlation histogram kurt : -...
# 82    TMS  59034375  $tms [2016-may] correlation histogram kurt : -...
# 83    TMS  59404150  $ebio telling every on to get on this for week...
# 84    TMS  59408679  $ebio $lgcy $mgt $thm $tms $gale $opgn $optt $...
# 85    TMS  82336324                              $tms $tmo $teva $mdrx
#
#                          date  sent  id_user   foll  ideas  \
# 0   2010-02-23 20:48:17+00:00     0     5644    970  10636
# 1   2010-03-04 14:48:43+00:00     0     5644    970  10636
# 2   2011-04-11 14:37:39+00:00     0    37943    123   1131
# 3   2011-04-11 15:16:05+00:00     0    67015  81321   6681
# 4   2011-04-13 14:52:44+00:00     0    67015  81321   6681
# ..                        ...   ...      ...    ...    ...
# 81  2016-07-14 15:10:24+00:00     0   594906     72  61098
# 82  2016-07-23 17:26:46+00:00     0   594906     72  61098
# 83  2016-07-28 18:22:09+00:00     0   737239     88   2147
# 84  2016-07-28 18:58:17+00:00     0   298451     38   3632
# 85  2017-05-07 12:45:18+00:00     1  1020839      0     19
#
#                                            clean_text  sent_new  sent_merged  \
# 0   damn now you know my secret but really do like...         1            1
# 1   seem to like that fix be still flaw why the re...        -1            0
# 2                rt ipos plan for the week of apr ipo         0            1
# 3     watch kathy smith talk this weeks on cbnc today         1            1
# 4   other ipos also expect to trade tomorrow box s...         1            1
# ..                                                ...       ...          ...
# 81           may correlation histogram kurt skew mode        -1           -1
# 82           may correlation histogram kurt skew mode        -1           -1
# 83  tell every on to get on this for week know lot...         1            1
# 84                              whats your thought on         1            1
# 85                                                NaN         0            1
#
#     sent_new_noros  bullish_proba
# 0                1       0.946411
# 1                0       0.621551
# 2                1       0.813679
# 3                1       0.899648
# 4                1       0.928247
# ..             ...            ...
# 81              -1       0.498839
# 82              -1       0.498839
# 83               1       0.898402
# 84               1       0.961670
# 85               1       0.842373
#
# [86 rows x 13 columns]

# %%
import pandas as pd

# Ruta del archivo CSV grande
file_path = 'df_withcorona_clean_1_with_proba_opti_and_hour.csv'

# Define el tamaño del chunk en términos de número de filas
chunk_size = 10000  # Ajusta este número según lo necesites

# Inicializa una lista para acumular los chunks filtrados
filtered_chunks = []

# Itera sobre el archivo CSV en chunks
for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    #print(f"Procesando chunk {i+1}")
    
    # Filtrar los registros que tienen "GOOGL" en la columna 'ticker'
    filtered_chunk = chunk[chunk['ticker'] == 'GOOGL']
    
    # Muestra 10 ejemplos de filas filtradas (si existen)
    if not filtered_chunk.empty:
        #print("Ejemplos de filas filtradas en este chunk:")
        #print(filtered_chunk.head(10))
        
        # Acumular los chunks filtrados
        filtered_chunks.append(filtered_chunk)

# Concatenar todos los chunks filtrados en un nuevo DataFrame
filtered_df = pd.concat(filtered_chunks, ignore_index=True)

# Guardar el nuevo DataFrame filtrado en un archivo CSV
filtered_df.to_csv('filtered_googl_records.csv', index=False)

print("Proceso completado. Los registros filtrados se han guardado en 'filtered_asml_records.csv'.")
# Out:
# Proceso completado. Los registros filtrados se han guardado en 'filtered_asml_records.csv'.

# %%
display(filtered_df)
# Out:
#      ticker    id_msg                                                msg  \
# 0      ASML   1012690  early selling (1,200x) in the mar 32.50 puts f...
# 1      ASML   1157559  looks like a put spread being built in $asml f...
# 2      ASML   1508751  i&#39;ve posted a vol trade at voltrader blog ...
# 3      ASML   1510203  i&#39;ve posted a vol trade at voltrader blog ...
# 4      ASML   1528110  i&#39;ve posted an update to $asml bearish dia...
# ...     ...       ...                                                ...
# 2627   ASML  97594594  price target alert: trading the zacks price ta...
# 2628   ASML  97618418                    $asml 2ng upgrade in 10 minutes
# 2629   ASML  97622501  $asml  new high .. $amat new high  ..  all goo...
# 2630   ASML  97631010  $c $jpm $xlf banks didn&#39;t fail 2 dissapoin...
# 2631   ASML  97633934  $asml releasing earnings on 10/18 before open ...
#
#                            date  sent  id_user   foll   ideas  \
# 0     2010-01-28 14:48:35+00:00     0      259  46692    9200
# 1     2010-03-12 16:13:17+00:00     0      259  46692    9200
# 2     2010-06-17 22:08:00+00:00     0     2127    223     474
# 3     2010-06-18 14:11:25+00:00     0     2127    223     474
# 4     2010-06-24 13:48:36+00:00     0     2127    223     474
# ...                         ...   ...      ...    ...     ...
# 2627  2017-10-12 14:27:33+00:00     0   403382  41921   55900
# 2628  2017-10-12 16:13:30+00:00     0   995834    531   10898
# 2629  2017-10-12 16:33:26+00:00     0   349810  42938  149376
# 2630  2017-10-12 17:16:26+00:00     1  1063472     57    2405
# 2631  2017-10-12 17:29:28+00:00     0   347689  15453  121845
#
#                                              clean_text  sent_new  \
# 0                      early selling in the mar put for        -1
# 1       look like put spread be build in for post ep on         0
# 2     ive post vol trade at voltrader blog bearish d...        -1
# 3     ive post vol trade at voltrader blog bearish d...        -1
# 4     ive post an update to bearish diagonal spread ...        -1
# ...                                                 ...       ...
# 2627  price target alert trade the zacks price targe...         1
# 2628                               ng upgrade in minute         1
# 2629                         new high new high all good         1
# 2630  bank didnt fail dissapoint fund scramble get i...        -1
# 2631  release earning on before open confirm anybody...         0
#
#       sent_merged  sent_new_noros  bullish_proba
# 0              -1              -1       0.114604
# 1               1               1       0.847155
# 2              -1              -1       0.302451
# 3              -1              -1       0.302451
# 4              -1              -1       0.276923
# ...           ...             ...            ...
# 2627            1               1       0.964660
# 2628            1               1       0.963393
# 2629            1               1       0.994754
# 2630            1               1       0.803171
# 2631            1               1       0.748017
#
# [2632 rows x 13 columns]

# %%
import pandas as pd

# Ruta del archivo CSV grande
file_path = 'df_withcorona_clean_1_with_proba_opti_and_hour.csv'

# Define el tamaño del chunk en términos de número de filas
chunk_size = 10000  # Ajusta este número según lo necesites

# Inicializa una lista para acumular los chunks filtrados
filtered_chunks = []

# Itera sobre el archivo CSV en chunks
for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    #print(f"Procesando chunk {i+1}")
    
    # Filtrar los registros que tienen "TMS" en la columna 'ticker'
    filtered_chunk = chunk[chunk['ticker'] == 'LRCX']
    
    # Muestra 10 ejemplos de filas filtradas (si existen)
    if not filtered_chunk.empty:
        #print("Ejemplos de filas filtradas en este chunk:")
        #print(filtered_chunk.head(10))
        
        # Acumular los chunks filtrados
        filtered_chunks.append(filtered_chunk)

# Concatenar todos los chunks filtrados en un nuevo DataFrame
filtered_df = pd.concat(filtered_chunks, ignore_index=True)

# Guardar el nuevo DataFrame filtrado en un archivo CSV
filtered_df.to_csv('filtered_LRCX_records.csv', index=False)

print("Proceso completado. Los registros filtrados se han guardado en 'filtered_asml_records.csv'.")
# Out:
# Proceso completado. Los registros filtrados se han guardado en 'filtered_asml_records.csv'.

# %%
display(filtered_df )
# Out:
#      ticker    id_msg                                                msg  \
# 0      LRCX    547789  morgan stanley on tech: upgrades $altr, $pmcs,...
# 1      LRCX    556219  $lrcx has a good trend break on the weekly cha...
# 2      LRCX    565820  $lrcx trying to confirm the weekly breakout. i...
# 3      LRCX    733048                                  short $lrcx 33.34
# 4      LRCX    737926                           covered $lrcx for a gain
# ...     ...       ...                                                ...
# 6755   LRCX  97623230  stocks set glum tone; utilities, dairy up: htt...
# 6756   LRCX  97623455  $lrcx since last er, stock gained 9%. reportin...
# 6757   LRCX  97631010  $c $jpm $xlf banks didn&#39;t fail 2 dissapoin...
# 6758   LRCX  97632587  $amd downtrend broke . chips look good  $nvda ...
# 6759   LRCX  97634427  $stmp $lrcx $snps $slab $noc $rtn $lmt they hi...
#
#                            date  sent  id_user    foll   ideas  \
# 0     2009-09-08 14:12:52+00:00     0     1544      30     499
# 1     2009-09-10 14:41:46+00:00     0      397      80     489
# 2     2009-09-14 15:51:32+00:00     0      397      80     489
# 3     2009-11-02 14:40:03+00:00     0       78  130496   33684
# 4     2009-11-03 14:47:15+00:00     0       78  130496   33684
# ...                         ...   ...      ...     ...     ...
# 6755  2017-10-12 16:37:26+00:00     0    87930   71386   10087
# 6756  2017-10-12 16:38:41+00:00     0   347689   15478  123970
# 6757  2017-10-12 17:16:26+00:00     1  1063472      56    2405
# 6758  2017-10-12 17:23:29+00:00     0   349810   43313  151594
# 6759  2017-10-12 17:31:40+00:00     0   433942    3926   77617
#
#                                              clean_text  sent_new  \
# 0                        morgan stanley on tech upgrade         1
# 1             have good trend break on the weekly chart         1
# 2     try to confirm the weekly breakout its up alth...         1
# 3                                                 short        -1
# 4                                        cover for gain        -1
# ...                                                 ...       ...
# 6755               stock set glum tone utility dairy up         1
# 6756  since last er stock gain report earning on aft...         1
# 6757  bank didnt fail dissapoint fund scramble get i...        -1
# 6758                     downtrend break chip look good         1
# 6759  they hide in big cap today some rotation under...        -1
#
#       sent_merged  sent_new_noros  bullish_proba
# 0               1               1       0.924942
# 1               1               1       0.881578
# 2               1               1       0.939821
# 3              -1              -1       0.101744
# 4               0               0       0.596063
# ...           ...             ...            ...
# 6755            1               1       0.963983
# 6756            1               1       0.934914
# 6757            1               1       0.803171
# 6758            1               1       0.953001
# 6759            0               0       0.532226
#
# [6760 rows x 13 columns]

# %%
import pandas as pd

# Ruta del archivo CSV grande
file_path = 'df_withcorona_clean_1_with_proba_opti_and_hour.csv'

# Define el tamaño del chunk en términos de número de filas
chunk_size = 10000  # Ajusta este número según lo necesites

# Inicializa una lista para acumular los chunks filtrados
filtered_chunks = []

# Itera sobre el archivo CSV en chunks
for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunk_size)):
    #print(f"Procesando chunk {i+1}")
    
    # Filtrar los registros que tienen "TMS" en la columna 'ticker'
    filtered_chunk = chunk[chunk['ticker'] == 'NVDA']
    
    # Muestra 10 ejemplos de filas filtradas (si existen)
    if not filtered_chunk.empty:
        #print("Ejemplos de filas filtradas en este chunk:")
        #print(filtered_chunk.head(10))
        
        # Acumular los chunks filtrados
        filtered_chunks.append(filtered_chunk)

# Concatenar todos los chunks filtrados en un nuevo DataFrame
filtered_df = pd.concat(filtered_chunks, ignore_index=True)

# Guardar el nuevo DataFrame filtrado en un archivo CSV
filtered_df.to_csv('filtered_NVDA_records.csv', index=False)

print("Proceso completado. Los registros filtrados se han guardado en 'filtered_NVDArecords.csv'.")
# Out:
# Proceso completado. Los registros filtrados se han guardado en 'filtered_NVDArecords.csv'.

# %%
len(filtered_df)
# Out:
# 213322
